# %% [markdown]
# # Assignment #5
#
# In this assignment we will start plotting data. You may choose to complete this assignment in either _R_ or _Python_. Please designate your choice in the first box.
#
# __Make sure your kernel is selected for the language you choose.__
#
# We will be using the county demographics data set on the server at _/shared/dsc495/county_demographics.csv_.
#
# You must complete the entire assignment in **1** language.

# %% [markdown]
# **Programming language:**

# %%
# import statements
list.files(path = '/shared/dsc495')
df = read.table(file = "/shared/dsc495/county_demographics.csv", header = TRUE, sep=",")

# %% [markdown]
# ## Q1: Read in the county demographics data.

# %%
df = read.table(file = "/shared/dsc495/county_demographics.csv", header = TRUE, sep=",")

# %% [markdown]
# ## Q2: Select a column you are interested in exploring further. Calculate its mean and standard deviation

# %%
dfs = df$Age.Percent.Under.5.Years
mean(df$Age.Percent.Under.5.Years)
sd(dfs)
head(df,5)
# Out:
# [1] 5.895291
# [1] 1.218243
#   County         State Age.Percent.65.and.Older Age.Percent.Under.18.Years
# 1 Autauga County AL    13.8                     25.2
# 2 Baldwin County AL    18.7                     22.2
# 3 Barbour County AL    16.5                     21.2
# 4 Bibb County    AL    14.8                     21.0
# 5 Blount County  AL    17.0                     23.6
#   Age.Percent.Under.5.Years Education.Bachelor.s.Degree.or.Higher
# 1 6.0                       20.9
# 2 5.6                       27.7
# 3 5.7                       13.4
# 4 5.3                       12.1
# 5 6.1                       12.1
#   Education.High.School.or.Higher Employment.Nonemployer.Establishments
# 1 85.6                             2947
# 2 89.1                            16508
# 3 73.7                             1546
# 4 77.5                             1126
# 5 77.0                             3563
#   Employment.Private.Non.farm.Employment
# 1 10120
# 2 54988
# 3  6611
# 4  3145
# ...

# %% [markdown]
# ## Q3: Make two histograms of the data from the column and compare them.

# %%
hist(dfs)
# Out:
# Plot with title “Histogram of dfs”

# %% [markdown]
# **Comparison:**

# %% [markdown]
# ## Q4: Make a boxplot of the same column.

# %%
boxplot(dfs)
# Out:
# plot without title

# %% [markdown]
# ## Q5: Selecting an additional column, make a scatter plot of both columns.

# %%
plot(df$Age.Percent.65.and.Older,dfs)
# Out:
# plot without title
